# %% [markdown]
# <a href="https://colab.research.google.com/github/henrysulub/MCPi/blob/main/MCPi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import random as random
import math as math
import statistics as std
# from bokeh.plotting import figure, output_file, show
import plotly.graph_objects as go
import plotly.express as px
os.system('cls')
tries = 10
puntos = 100

def estimar_pi(puntos):
    in_circle_x = []
    in_circle_y = []
    out_circle_x = []
    out_circle_y = []
    pi_array =[]

    for i in range(puntos):
        pos_x = random.uniform(-1,1)
        pos_y = random.uniform(-1,1)

        if math.sqrt(pos_x**2 + pos_y**2) <= 1:
            in_circle_x.append(pos_x)
            in_circle_y.append(pos_y)
        else:
            out_circle_x.append(pos_x)
            out_circle_y.append(pos_y)

    estimate_pi = (4 * len(in_circle_x)) / puntos
    return (estimate_pi, in_circle_x, in_circle_y, out_circle_x, out_circle_y)
    #return ()

def crear_muestra(tries):
    pi_array =[]
    for i in range(tries):
        pivalor,in_circle_x, in_circle_y, out_circle_x, out_circle_y = estimar_pi(puntos)
        pi_array.append(pivalor)
    return (pi_array, in_circle_x, in_circle_y, out_circle_x, out_circle_y)

deviation = 1       # Valor inicial para poder empezar el ciclo while
presicion = 0.1     # Precision en cifras significativas para determinar el
                    # valor estimado de pi (CUIDADO!!!!)

iteration = 1

if __name__ == '__main__':
    while deviation >= (presicion / 3): # dividir entre 1.96 desviaciones standar para una precicion del 95%
        pi_array, in_circle_x, in_circle_y, out_circle_x, out_circle_y = crear_muestra(tries)
        deviation = std.stdev(pi_array)
        variance = std.variance(pi_array)
        mean = std.mean(pi_array)

        print(f'------------------       Iteracion number: {(iteration)}      ------------------')
        print(f'Standard deviation: {round(deviation,5)}, Variance : {round(variance,5)}, pi estimated: {round(mean,5)}')
        print(f'Numero de intentos {tries}, Numero de puntos {puntos}\n\n')
        #print(f)

        fig1 = px.scatter(x=in_circle_x,
                    y=in_circle_y,
                    opacity = 1,
                    render_mode = 'auto')

        fig1.update_traces(marker=dict(color='red'),
                    showlegend=True)

        fig2 = px.scatter(x=out_circle_x,
                    y=out_circle_y,
                    opacity = 1,
                    render_mode = 'auto')

        fig2.update_traces(marker=dict(color='blue'),
                    showlegend=True)

        fig3 = go.Figure(data=fig1.data + fig2.data)

        fig3.update_layout(title = f'Calculo de Pi por metodo montecarlo, numero de intentos {tries} y Numero de puntos {puntos}',
                    font = dict(family = 'verdana', size = 16, color = 'white'),
                    template = 'plotly_dark',
                    height = 1150,
                    width = 1150,
                    legend_bgcolor='rgb(117, 112, 179)')

        fig3.show()
        print('\n')

        puntos *= 10
        tries *= 10
        iteration += 1
# Out:
# ------------------       Iteracion number: 1      ------------------
# Standard deviation: 0.15226, Variance : 0.02318, pi estimated: 3.136
# Numero de intentos 10, Numero de puntos 100
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3be9eb2f-2d4a-4b9c-a065-60b3375f93f2" class="plotly-graph-div" style="height:1150px; width:1150px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3be9eb2f-2d4a-4b9c-a065-60b3375f93f2")) {                    Plotly.newPlot(                        "3be9eb2f-2d4a-4b9c-a065-60b3375f93f2",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"red","opacity":1,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":true,"x":[0.1034024036658876,-0.7719381063777206,-0.050363895892321375,-0.45445740902576093,-0.17018969497766134,0.47999556506477625,0.7460876080912282,0.39306900798665634,0.09776707771757676,-0.7784558825862238,0.2683930638464951,0.7172567918481045,0.02849757222540128,-0.3057557427664159,0.258496978976972,-0.9720303425115469,-0.6608194093591244,-0.37786780856996804,0.21117686093590926,-0.5885768586057674,-0.5630683744655351,0.3860177025872371,0.540514529997606,0.19473084215401615,-0.45507086527371743,-0.5540685756092996,0.43202790655930245,-0.418624574639308,-0.4419599770003455,0.7924318949079439,0.7907335503366737,0.8734548569529708,-0.7578927350950204,-0.8162959103114666,-0.06913288415862384,-0.36747286105457744,0.1503961815112309,-0.06829257135984257,-0.6788145425923591,0.8215459355634545,0.06220545190673943,-0.33330071197310196,-0.3654670201220136,0.07568509449568683,-0.2940957213769728,0.8109520387558069,0.12395610880475028,-0.3516406149852136,-0.3862278173472391,0.17279121093498073,0.7255456646142946,0.1694746967896854,-0.6166243382822416,0.5042405907096068,-0.33182157101407417,0.3705059686099921,-0.6889232650375485,0.12417120653975688,-0.9171748831643725,-0.5086779470578608,0.6668881190410847,-0.8855403680155733,-0.43455458072655584,-0.013867092432925832,-0.7195534236182177,-0.3725487537714729,-0.39273620501749096,-0.5458461583302936,-0.586000337812921,0.25204156969607006,0.2849755229925157,0.5196230551645302,0.45210451054219725,0.7318815272201507,-0.7456028073151708,0.18423291550382914,-0.4189256723680006,0.872481411317966,0.5295340202327643,-0.4613382634263534,0.5260468000870853,-0.6130495497846415,-0.8886051325936681],"xaxis":"x","y":[0.033122757031400996,-0.16729720335852138,-0.5667925150234714,-0.7986941214731973,-0.6633118151065247,-0.6989387600321222,0.33108173369393135,-0.22945596642311306,-0.1837219334248903,0.5035402902024226,-0.036812090499265704,-0.3601222856028219,-0.13993229542490404,0.15301882786679744,0.664914326280176,-0.20280153338933737,0.4218718478421579,0.7260631261675441,0.062287965526178324,-0.24949279265116742,-0.7980021351069722,-0.6548256249831659,-0.54938678596383,-0.04348795985185361,-0.25057267042368014,0.698942322436622,0.3420574378913952,0.4411377104088363,-0.4996481542030762,-0.02636322630319987,-0.1658217981775758,0.06215807014835173,0.17437994959969583,0.07697736239797104,-0.5752376525638292,-0.42546850974391126,-0.30888496944861465,0.16188344854200265,-0.08865021468025791,0.09409670430963768,-0.42890357581755345,-0.9040686213952416,-0.19805455888618972,-0.9554167679217458,0.7084084687524015,0.3895177275672108,0.536031275496361,0.6035188722366358,-0.4354457970595327,-0.6638380288885486,-0.2117956027982444,0.7706370932567117,0.1642425920146735,-0.3763221415293845,0.06881740976908146,0.7124417475972875,-0.6819553082679886,0.1641648994938376,-0.3833125773237742,-0.4030784682130555,-0.26176575326331286,0.3566045586181561,-0.51902463397753,-0.5859811698762116,-0.6702792002110918,-0.9046358089622626,-0.5440953316758863,0.7865724423025906,0.03309851099889505,0.017455127412054905,0.9221415243631643,0.3516381072334769,-0.8167199028404035,0.459439796932096,-0.32826735050176126,-0.14015475323802162,0.19683517040982212,-0.3124164 ...
# ------------------       Iteracion number: 2      ------------------
# Standard deviation: 0.04766, Variance : 0.00227, pi estimated: 3.14424
# Numero de intentos 100, Numero de puntos 1000
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e08350d3-f763-4140-bb08-6130c1357edf" class="plotly-graph-div" style="height:1150px; width:1150px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e08350d3-f763-4140-bb08-6130c1357edf")) {                    Plotly.newPlot(                        "e08350d3-f763-4140-bb08-6130c1357edf",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"red","opacity":1,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":true,"x":[0.1935002585479666,-0.3857462460573233,0.7491646048227096,0.6815664259222682,-0.6550395895714738,-0.21753522157465088,0.5340542493203269,0.016287291318414665,-0.6910428987967032,0.40925596411281995,0.020484334204734278,-0.5657231179591993,-0.12835500091299212,-0.37280707565460425,0.3512929038672796,-0.8847689305721151,-0.5189712701915035,-0.2644846696627572,0.20059867086548633,-0.8579478680254606,-0.8513728746611311,0.5711672763075795,-0.6936704216700422,0.7141881054911656,0.49125813704099475,0.136218488254098,0.508873990220506,0.3527417409918405,0.41975715327492735,0.7190956549647824,0.5140841084569332,0.18055937398875144,0.7053684109155043,-0.16965793495866333,-0.49828026797080693,-0.6738877917839796,-0.0031384430164413946,-0.3198904820693955,0.6061108584751711,-0.19600613703637615,0.10838199441918661,0.7098977381621598,0.9568056378161711,0.22156371660295937,-0.16589917856316894,0.6873403693681317,0.36788375281354635,0.5169349784300501,0.9698256897561939,-0.41372737748270483,0.5441074409992073,0.3915492415711235,0.6925752772913893,0.4545532634801994,-0.891956461997194,-0.67113993263563,0.6412833062299936,0.6358942599999207,0.21239456278268487,-0.1648627122453148,0.8327155481668831,-0.4034935858069162,-0.186428793938904,-0.4154033235303678,-0.02614436469302306,0.052659680296722744,0.1321808474666244,0.014364584215126097,0.7200996983359242,-0.8751735323633125,0.515623973045406,0.918521958262893,-0.09122006387727022,-0.0038362612385585138,-0.04615941672256274,0.2772219138161185,-0.38186301380853105,0.5051660196020507,-0.28634439201280326,-0.2662511258229725,-0.9018922696010496,0.06173505647785915,0.14746647202086338,-0.45232405083828775,-0.8023924337084576,0.034526295952096,0.8554114008367966,0.6083304659458764,0.19770828560246367,-0.03976481606905424,-0.20268125588394836,-0.008452167738333793,0.2069924245488508,-0.41713656455946047,0.762745842848155,-0.7009916355934147,0.23989295715591785,0.9609940581571634,-0.30886981562404614,-0.08004649839796896,-0.617786461255744,0.6600803218170661,-0.5595064606279518,-0.4840750168518584,-0.30216344554657115,0.22267646314367928,0.48896321061688797,-0.7793902506754966,-0.8709148546447814,-0.3131098951696385,0.928693171607931,-0.6016105503210474,0.7164171029545621,-0.1124080267095875,0.24949470446588995,0.07708193137046448,0.4001012767745178,-0.83660006764501,-0.1745283986087831,0.1435470956489835,0.0470987512431571,-0.07411399521575235,0.18557991945316465,-0.07161031408025353,-0.241255372971118,0.7039600253443836,-0.8957170288377541,0.77691046329044,0.27304419101208244,-0.654587261703085,-0.5207009776190985,0.5047758842711427,-0.06198050209335215,-0.1966725496252144,0.6899098616713726,-0.4489832138405023,-0.8562942736506323,0.62183215951416,-0.17084702119867878,-0.026131165248106436,-0.7190481095714261,0.7203617671046121,-0.26108827933115264,-0.09224483743516476,-0.6578515942609544,-0.7810727146801761,-0.6264328423796519,-0.4074423120229964,0.8625524535728581,0.3496256478051758,0.14983632254964108,0.1935500787110489,0.6254448748410799,0.5596337117908001,-0.9082036454046163,-0.02991453830354107,0.07891613178246315,-0.6082095160482621,0.648245643168414,-0.06444859487192778,0.17746807555252042,0.9937747219182962,-0. ...
# ------------------       Iteracion number: 3      ------------------
# Standard deviation: 0.01629, Variance : 0.00027, pi estimated: 3.14145
# Numero de intentos 1000, Numero de puntos 10000
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="40e379e1-e8ea-4e8d-9282-70b33acfdb1f" class="plotly-graph-div" style="height:1150px; width:1150px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40e379e1-e8ea-4e8d-9282-70b33acfdb1f")) {                    Plotly.newPlot(                        "40e379e1-e8ea-4e8d-9282-70b33acfdb1f",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"red","opacity":1,"symbol":"circle"},"mode":"markers","name":"","showlegend":true,"x":[0.5318019483688994,-0.459307682910284,0.02966534849556024,-0.3973396288803932,-0.05127064504797474,-0.332962261800571,-0.14353601319021725,0.5306934665867666,-0.33640339742720116,-0.04142162476572264,-0.40560180124124456,0.08385064790094576,-0.4762173550714395,0.8424899012241414,0.298456686225524,-0.13359135045356263,-0.3463840509030649,0.08277536321869405,0.990811604553903,0.3238373581931302,0.06303914633260566,-0.4499556790203738,-0.700750628595272,0.967450325903606,-0.6392600843670477,-0.014156728810295283,0.8481018755303609,-0.29316686977023076,0.16497302734531272,-0.6618643677824907,-0.4794862767964816,-0.2766648031880361,-0.3003897729232343,0.8539909748447878,-0.5286454048479743,-0.1412991543815032,-0.5158828544974712,0.15831630403989094,-0.711416319602872,0.4476981301096823,-0.7894000777104426,0.8561701367961598,0.7369397459009663,-0.532604110386879,-0.29039771189321084,-0.3865624539746275,-0.12370396042216458,-0.4409841108791879,0.46036340866517667,0.6782988864547479,-0.5059411897878348,0.6888215439905503,-0.47408136301028714,-0.041876829474355226,0.06956673475972508,0.2509724049819009,-0.3708811112080215,0.5481226454275441,0.3316627168067241,0.5885852964521849,-0.28006328448467865,0.7545076322661761,0.43855670354239984,-0.6814035237863081,-0.6582095924030447,0.12280611047085244,-0.675559565781358,0.7490992049580041,-0.8335815621687956,-0.581912612900858,-0.4188151627751906,0.38389849572972334,-0.32979895262110936,0.7470365046517669,-0.25399279050332235,-0.006608803518425077,-0.18625201439371253,-0.8432613236505337,-0.4143045792061366,-0.783573484084138,-0.1828952339250567,0.06742101932956412,-0.5188924362033236,-0.18872813068357064,-0.18682640816552332,0.5122947572405343,-0.7079894497576542,0.2511806870849138,-0.1346609091479105,-0.9782139198491984,-0.7341346379462124,-0.7403254083897295,-0.7105816624097088,0.43989779891782477,-0.17372355975778286,-0.7543447909705252,-0.37792750539337616,0.35947932229917856,-0.06317616157320205,-0.704264018955483,0.22951198175186915,0.5134461156900585,-0.7010425028988918,-0.18128081907185822,0.6170968248477242,-0.03919993638977792,0.7556799410580632,-0.14034490787260756,-0.0924748538145237,0.8421982262524443,0.5670525231779877,0.6080027670666737,0.8399825291679792,-0.6457099838927223,0.3136156098556284,0.6546748679506433,-0.20555179344746932,0.5065954308529828,-0.867382427827978,-0.9925432158317051,0.12701069123056086,0.6318248474103068,0.27908840971786586,0.5767907456025363,0.6063444963540241,-0.05377122254228994,0.5801366755400945,0.15926998000442416,0.11988812952691141,0.4407139672692808,0.5321669613293691,0.8376133861668658,-0.8836823425322347,0.8303021162293289,-0.28002075551907457,0.17903085754179737,-0.6240620729940911,0.42499525453456655,-0.6056122891915159,-0.11275907732828827,0.7600566730588809,0.43586467021056086,0.7347643281628944,-0.11320286849968442,0.2853735206473771,0.1327284297798914,0.7373544231907148,0.8048190583827326,-0.6477866824612342,-0.5824904953067058,0.7614046993662023,-0.10454699343106322,0.8418009427599971,-0.8598288843641115,0.19273309102115688,-0.2536228241645484,0.0916844695430119,0.8927295780419329,0.12551089441611718,-0.12607943914671127,0.06398881397861489,-0.08575818352763442,0.52369070310 ...
